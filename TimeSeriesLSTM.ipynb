# %% [markdown]
# # LSTM & Time Series Prediction
# Khảo sát mô hình LSTM trong mạng neural hồi quy trong vấn đề dự đoán với dữ liệu chuỗi thời gian

# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
import torch

# %% [markdown]
# Kiểm tra pytorch có đang dùng GPU không? Nguồn: https://stackoverflow.com/a/53374933

# %%
# setting device on GPU if available, else CPU
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Using device:', device)
# Out:
# Using device: cuda

# %% [markdown]
# ## 1. Chuẩn bị dữ liệu và biểu diễn dữ liệu
# ### 1.1. Mô tả về dữ liệu biến động giá trị giữa đồng USD và GBP (bảng Anh)

# %%
dataset_path = "./Datasets/USD_GBP.txt"
data = np.loadtxt(dataset_path)

# %% [markdown]
# Biểu diễn dữ liệu

# %%
plt.plot(data)
plt.ylabel("USD-GBP exchange rate")
plt.show()

# %% [markdown]
# ### 1.2 Sơ lược về mục tiêu & kết qủa mong đợi của khảo sát

# %% [markdown]
# ## 2. Xây dựng mô hình LSTM
# ### 2.1 Khảo sát mô hình LSTM được xây dựng mặc định bởi Pytorch

# %%
class LSTM
